# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | neiafu
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | vestmanna
# Processing Record 8 of Set 1 | trairi
# Processing Record 9 of Set 1 | newport
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | namie
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | itaituba
# Processing Record 17 of Set 1 | tarauaca
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | sao joao da barra
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | boa vista
# Processing Record 22 of Set 1 | woodward
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | manado
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | petauke
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | novichikha
# Processing Record 32 of Set 1 | vila velha
# Processing Record 33 of Set 1 | augustow
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | acari
# Processing Record 36 of Set 1 | nabire
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | itai
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | ixtapa
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | abu samrah
# Processing Record 47 of Set 1 | lasa
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | husavik
# Processing Record 50 of Set 1 | samarai
# Processing Record 1 of Set 2 | shimoda
# Processing Record 2 of Set 2 | kununurra
# Processing Record 3 of Set 2 | bozoum
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | acarau
# Processing Record 8 of Set 2 | bermejo
# Processing Record 9 of Set 2 | chase
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | kerman
# Processing Record 14 of Set 2 | zhigalovo
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | dengzhou
# Processing Record 17 of Set 2 | le port
# Processing Record 18 of Set 2 | arlit
# Processing Record 19 of Set 2 | brownsville
# Processing Record 20 of Set 2 | phuket
# Processing Record 21 of Set 2 | kieta
# Processing Record 22 of Set 2 | gladstone
# Processing Record 23 of Set 2 | aasiaat
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | andros town
# Processing Record 27 of Set 2 | hervey bay
# Processing Record 28 of Set 2 | sangar
# Processing Record 29 of Set 2 | broken hill
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | pontes e lacerda
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | ilo
# Processing Record 34 of Set 2 | karratha
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | hambantota
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | waingapu
# Processing Record 43 of Set 2 | ilka
# City not found. Skipping...
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | eldorado
# Processing Record 47 of Set 2 | grindavik
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | tiznit
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | asilah
# Processing Record 6 of Set 3 | oak ridge
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | tura
# Processing Record 9 of Set 3 | dumai
# Processing Record 10 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 3 | juba
# Processing Record 12 of Set 3 | mamallapuram
# Processing Record 13 of Set 3 | xining
# Processing Record 14 of Set 3 | sao domingos do prata
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | nelson bay
# Processing Record 17 of Set 3 | belaya
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | concarneau
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | piacabucu
# Processing Record 25 of Set 3 | port hawkesbury
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | brewster
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | espergaerde
# Processing Record 30 of Set 3 | hirara
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | zarand
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | siyabuswa
# Processing Record 41 of Set 3 | xuddur
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 3 | hermanus
# Processing Record 45 of Set 3 | araouane
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | muli
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | sechura
# Processing Record 1 of Set 4 | grand gaube
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | nedjo
# Processing Record 4 of Set 4 | kungurtug
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | cotacachi
# Processing Record 7 of Set 4 | khasan
# Processing Record 8 of Set 4 | hachinohe
# Processing Record 9 of Set 4 | mogwase
# Processing Record 10 of Set 4 | ulaangom
# Processing Record 11 of Set 4 | coihaique
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | saint anthony
# Processing Record 15 of Set 4 | altay
# Processing Record 16 of Set 4 | nara
# Processing Record 17 of Set 4 | maragogi
# Processing Record 18 of Set 4 | broome
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | mogadishu
# Processing Record 21 of Set 4 | puerto gaitan
# Processing Record 22 of Set 4 | mattru
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | cap-aux-meules
# Processing Record 25 of Set 4 | dingle
# Processing Record 26 of Set 4 | felanitx
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | cabatuan
# Processing Record 29 of Set 4 | praia da vitoria
# Processing Record 30 of Set 4 | mackay
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | russellville
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | bluff
# Processing Record 35 of Set 4 | vaasa
# Processing Record 36 of Set 4 | narsaq
# Processing Record 37 of Set 4 | bathsheba
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | nsanje
# Processing Record 40 of Set 4 | sumenep
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | rocha
# Processing Record 43 of Set 4 | tezu
# Processing Record 44 of Set 4 | troitskoye
# Processing Record 45 of Set 4 | niles
# Processing Record 46 of Set 4 | yerbogachen
# Processing Record 47 of Set 4 | dubuque
# Processing Record 48 of Set 4 | bilibino
# Processing Record 49 of Set 4 | sabang
# Processing Record 50 of Set 4 | balikpapan
# Processing Record 1 of Set 5 | dickinson
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | beihai
# Processing Record 4 of Set 5 | vila
# Processing Record 5 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 5 | saint-louis
# Processing Record 7 of Set 5 | smithers
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | tarnaveni
# City not found. Skipping...
# Processing Record 11 of Set 5 | tessaoua
# Processing Record 12 of Set 5 | saquarema
# Processing Record 13 of Set 5 | kamenka
# Processing Record 14 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 15 of Set 5 | dauriya
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 5 | paka
# Processing Record 19 of Set 5 | pedasi
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | hanna
# Processing Record 22 of Set 5 | obera
# Processing Record 23 of Set 5 | namibe
# Processing Record 24 of Set 5 | batemans bay
# Processing Record 25 of Set 5 | rosetta
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | luganville
# Processing Record 28 of Set 5 | tomatlan
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | richards bay
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | port alfred
# Processing Record 34 of Set 5 | fountain hills
# Processing Record 35 of Set 5 | santa marta
# Processing Record 36 of Set 5 | mattawa
# Processing Record 37 of Set 5 | torzhok
# Processing Record 38 of Set 5 | platteville
# Processing Record 39 of Set 5 | iquique
# Processing Record 40 of Set 5 | kijang
# Processing Record 41 of Set 5 | canico
# Processing Record 42 of Set 5 | mahebourg
# Processing Record 43 of Set 5 | bethel
# Processing Record 44 of Set 5 | eyl
# Processing Record 45 of Set 5 | dire
# Processing Record 46 of Set 5 | chernyshevskiy
# Processing Record 47 of Set 5 | geraldton
# Processing Record 48 of Set 5 | huainan
# Processing Record 49 of Set 5 | temir
# Processing Record 50 of Set 5 | wicklow
# Processing Record 1 of Set 6 | soto la marina
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | pyshchug
# Processing Record 4 of Set 6 | vanavara
# Processing Record 5 of Set 6 | sao bernardo do campo
# Processing Record 6 of Set 6 | byron bay
# Processing Record 7 of Set 6 | hoa binh
# Processing Record 8 of Set 6 | narayangarh
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | sosnovo-ozerskoye
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | vista hermosa
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | oriximina
# Processing Record 15 of Set 6 | puerto narino
# Processing Record 16 of Set 6 | kysyl-syr
# Processing Record 17 of Set 6 | ostersund
# Processing Record 18 of Set 6 | abonnema
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | mehamn
# Processing Record 21 of Set 6 | manikpur
# Processing Record 22 of Set 6 | inhambane
# Processing Record 23 of Set 6 | westport
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | andra
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | zabol
# Processing Record 29 of Set 6 | vila franca do campo
# Processing Record 30 of Set 6 | kailua
# Processing Record 31 of Set 6 | kropotkin
# Processing Record 32 of Set 6 | kulhudhuffushi
# Processing Record 33 of Set 6 | nome
# Processing Record 34 of Set 6 | mirina
# City not found. Skipping...
# Processing Record 35 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 6 | uvarovka
# Processing Record 37 of Set 6 | formosa do rio preto
# Processing Record 38 of Set 6 | zhireken
# Processing Record 39 of Set 6 | andenes
# Processing Record 40 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 6 | bay roberts
# Processing Record 42 of Set 6 | merauke
# Processing Record 43 of Set 6 | hailun
# Processing Record 44 of Set 6 | mangrol
# Processing Record 45 of Set 6 | oneida
# Processing Record 46 of Set 6 | fairbanks
# Processing Record 47 of Set 6 | kilindoni
# Processing Record 48 of Set 6 | thinadhoo
# Processing Record 49 of Set 6 | bonito
# Processing Record 50 of Set 6 | lavrentiya
# Processing Record 1 of Set 7 | prince george
# Processing Record 2 of Set 7 | pedernales
# Processing Record 3 of Set 7 | aksarka
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | buarcos
# Processing Record 6 of Set 7 | college
# Processing Record 7 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 7 | muscat
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | svetlogorsk
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 13 of Set 7 | dubbo
# Processing Record 14 of Set 7 | makakilo city
# Processing Record 15 of Set 7 | korhogo
# Processing Record 16 of Set 7 | wrexham
# Processing Record 17 of Set 7 | kutum
# Processing Record 18 of Set 7 | iskateley
# Processing Record 19 of Set 7 | srednekolymsk
# Processing Record 20 of Set 7 | yatou
# Processing Record 21 of Set 7 | ciudad bolivar
# Processing Record 22 of Set 7 | boulder
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | nemuro
# Processing Record 25 of Set 7 | minjur
# Processing Record 26 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 7 | uhlove
# Processing Record 28 of Set 7 | mullingar
# Processing Record 29 of Set 7 | upernavik
# Processing Record 30 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 7 | peniche
# Processing Record 32 of Set 7 | romilly-sur-seine
# Processing Record 33 of Set 7 | popondetta
# Processing Record 34 of Set 7 | vao
# Processing Record 35 of Set 7 | buala
# Processing Record 36 of Set 7 | usinsk
# Processing Record 37 of Set 7 | morrinhos
# Processing Record 38 of Set 7 | wuwei
# Processing Record 39 of Set 7 | mogochin
# City not found. Skipping...
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | chivilcoy
# Processing Record 42 of Set 7 | yaan
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | airai
# Processing Record 45 of Set 7 | zinder
# Processing Record 46 of Set 7 | praia
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | poronaysk
# Processing Record 49 of Set 7 | moron
# Processing Record 50 of Set 7 | mamonovo
# Processing Record 1 of Set 8 | ballitoville
# Processing Record 2 of Set 8 | oranjestad
# Processing Record 3 of Set 8 | leningradskiy
# Processing Record 4 of Set 8 | concordia
# Processing Record 5 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 8 | olafsvik
# Processing Record 7 of Set 8 | elizabeth city
# Processing Record 8 of Set 8 | bud
# Processing Record 9 of Set 8 | deputatskiy
# Processing Record 10 of Set 8 | dehui
# Processing Record 11 of Set 8 | skibbereen
# Processing Record 12 of Set 8 | nikolskoye
# Processing Record 13 of Set 8 | margate
# Processing Record 14 of Set 8 | cairns
# Processing Record 15 of Set 8 | port moresby
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | jardim
# Processing Record 18 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 8 | constitucion
# Processing Record 20 of Set 8 | dunedin
# Processing Record 21 of Set 8 | waipawa
# Processing Record 22 of Set 8 | udachnyy
# Processing Record 23 of Set 8 | najran
# Processing Record 24 of Set 8 | santa cruz de tenerife
# Processing Record 25 of Set 8 | hofn
# Processing Record 26 of Set 8 | jacareacanga
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | henties bay
# Processing Record 29 of Set 8 | lumut
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | lang suan
# Processing Record 32 of Set 8 | divnomorskoye
# Processing Record 33 of Set 8 | camacha
# Processing Record 34 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 8 | betul
# Processing Record 37 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 8 | saldanha
# Processing Record 39 of Set 8 | ternate
# Processing Record 40 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | darhan
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | dalvik
# Processing Record 45 of Set 8 | san felipe
# Processing Record 46 of Set 8 | union
# Processing Record 47 of Set 8 | tirodi
# Processing Record 48 of Set 8 | antibes
# Processing Record 49 of Set 8 | bundaberg
# Processing Record 50 of Set 8 | novo aripuana
# Processing Record 1 of Set 9 | kirakira
# Processing Record 2 of Set 9 | north bend
# Processing Record 3 of Set 9 | comodoro rivadavia
# Processing Record 4 of Set 9 | isla vista
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | karmana
# City not found. Skipping...
# Processing Record 7 of Set 9 | khandyga
# Processing Record 8 of Set 9 | san blas
# Processing Record 9 of Set 9 | ilebo
# Processing Record 10 of Set 9 | cariamanga
# Processing Record 11 of Set 9 | frontera
# Processing Record 12 of Set 9 | ossora
# Processing Record 13 of Set 9 | san policarpo
# Processing Record 14 of Set 9 | shakawe
# Processing Record 15 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 9 | porbandar
# Processing Record 17 of Set 9 | chara
# Processing Record 18 of Set 9 | srandakan
# Processing Record 19 of Set 9 | hovd
# Processing Record 20 of Set 9 | pimentel
# Processing Record 21 of Set 9 | mount gambier
# Processing Record 22 of Set 9 | yeppoon
# Processing Record 23 of Set 9 | kaliganj
# Processing Record 24 of Set 9 | dakar
# Processing Record 25 of Set 9 | la asuncion
# Processing Record 26 of Set 9 | naze
# Processing Record 27 of Set 9 | kismayo
# Processing Record 28 of Set 9 | bambanglipuro
# Processing Record 29 of Set 9 | chapais
# Processing Record 30 of Set 9 | asau
# Processing Record 31 of Set 9 | maba
# Processing Record 32 of Set 9 | avera
# Processing Record 33 of Set 9 | savannah bight
# Processing Record 34 of Set 9 | yarim
# Processing Record 35 of Set 9 | dinard
# Processing Record 36 of Set 9 | santiago
# Processing Record 37 of Set 9 | waseca
# Processing Record 38 of Set 9 | talnakh
# Processing Record 39 of Set 9 | candido mendes
# Processing Record 40 of Set 9 | severodvinsk
# Processing Record 41 of Set 9 | kasongo
# Processing Record 42 of Set 9 | kavieng
# Processing Record 43 of Set 9 | susangerd
# Processing Record 44 of Set 9 | ilulissat
# Processing Record 45 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 9 | sumbe
# Processing Record 47 of Set 9 | ballinrobe
# Processing Record 48 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 9 | kjollefjord
# Processing Record 50 of Set 9 | honiara
# Processing Record 1 of Set 10 | amapa
# Processing Record 2 of Set 10 | impfondo
# Processing Record 3 of Set 10 | beyneu
# Processing Record 4 of Set 10 | palana
# Processing Record 5 of Set 10 | gazli
# Processing Record 6 of Set 10 | esperance
# Processing Record 7 of Set 10 | marrakesh
# Processing Record 8 of Set 10 | olinda
# Processing Record 9 of Set 10 | svetlaya
# Processing Record 10 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 10 | balkhash
# Processing Record 12 of Set 10 | kisangani
# Processing Record 13 of Set 10 | sobradinho
# Processing Record 14 of Set 10 | chokwe
# Processing Record 15 of Set 10 | carballo
# Processing Record 16 of Set 10 | alice springs
# Processing Record 17 of Set 10 | vanimo
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | karachev
# Processing Record 20 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 10 | quatre cocos
# Processing Record 22 of Set 10 | fort nelson
# Processing Record 23 of Set 10 | korla
# Processing Record 24 of Set 10 | ukiah
# Processing Record 25 of Set 10 | warri
# Processing Record 26 of Set 10 | bairiki
# Processing Record 27 of Set 10 | keti bandar
# Processing Record 28 of Set 10 | te anau
# Processing Record 29 of Set 10 | queanbeyan
# Processing Record 30 of Set 10 | christchurch
# Processing Record 31 of Set 10 | gamba
# Processing Record 32 of Set 10 | ambulu
# Processing Record 33 of Set 10 | magsingal
# Processing Record 34 of Set 10 | zaria
# Processing Record 35 of Set 10 | mlonggo
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | shitkino
# Processing Record 38 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 10 | banjar
# Processing Record 40 of Set 10 | mariental
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | tefe
# Processing Record 43 of Set 10 | taksimo
# Processing Record 44 of Set 10 | tamiahua
# Processing Record 45 of Set 10 | yenagoa
# Processing Record 46 of Set 10 | pochutla
# Processing Record 47 of Set 10 | krutaya gorka
# Processing Record 48 of Set 10 | elko
# Processing Record 49 of Set 10 | nouakchott
# Processing Record 50 of Set 10 | tukrah
# Processing Record 1 of Set 11 | bubaque
# Processing Record 2 of Set 11 | omboue
# Processing Record 3 of Set 11 | codrington
# Processing Record 4 of Set 11 | khovu-aksy
# Processing Record 5 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 11 | montrose
# Processing Record 7 of Set 11 | sao joao de pirabas
# Processing Record 8 of Set 11 | hegang
# Processing Record 9 of Set 11 | muros
# Processing Record 10 of Set 11 | marawi
# Processing Record 11 of Set 11 | ndele
# Processing Record 12 of Set 11 | touros
# Processing Record 13 of Set 11 | aravissos
# Processing Record 14 of Set 11 | salalah
# Processing Record 15 of Set 11 | taltal
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | nouadhibou
# Processing Record 18 of Set 11 | tilichiki
# Processing Record 19 of Set 11 | bende
# Processing Record 20 of Set 11 | kasongo-lunda
# Processing Record 21 of Set 11 | saint-anselme
# Processing Record 22 of Set 11 | iqaluit
# Processing Record 23 of Set 11 | vuktyl
# Processing Record 24 of Set 11 | yarmouth
# Processing Record 25 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 26 of Set 11 | adelaide
# Processing Record 27 of Set 11 | bonnyville
# Processing Record 28 of Set 11 | alpena
# Processing Record 29 of Set 11 | maumere
# Processing Record 30 of Set 11 | pacific grove
# Processing Record 31 of Set 11 | sisimiut
# Processing Record 32 of Set 11 | mayumba
# Processing Record 33 of Set 11 | dongli
# Processing Record 34 of Set 11 | ndioum
# Processing Record 35 of Set 11 | rundu
# Processing Record 36 of Set 11 | ballina
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 11 | jibuti
# Processing Record 40 of Set 11 | doka
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 11 | faro
# Processing Record 44 of Set 11 | poya
# Processing Record 45 of Set 11 | baruun-urt
# Processing Record 46 of Set 11 | aller
# Processing Record 47 of Set 11 | rize
# Processing Record 48 of Set 11 | killybegs
# Processing Record 49 of Set 11 | hue
# Processing Record 50 of Set 11 | yongan
# Processing Record 1 of Set 12 | warrington
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 12 | snyder
# Processing Record 5 of Set 12 | harnosand
# Processing Record 6 of Set 12 | san rafael
# Processing Record 7 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | tambopata
# Processing Record 9 of Set 12 | hami
# Processing Record 10 of Set 12 | tabas
# Processing Record 11 of Set 12 | ulundi
# Processing Record 12 of Set 12 | awka
# Processing Record 13 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | xushan
# Processing Record 15 of Set 12 | fort saint james
# Processing Record 16 of Set 12 | honningsvag
# Processing Record 17 of Set 12 | juneau
# Processing Record 18 of Set 12 | duluth
# Processing Record 19 of Set 12 | nakamura
# Processing Record 20 of Set 12 | qaqortoq
# Processing Record 21 of Set 12 | soke
# Processing Record 22 of Set 12 | wanaka
# Processing Record 23 of Set 12 | tyukalinsk
# Processing Record 24 of Set 12 | kushima
# Processing Record 25 of Set 12 | walla walla
# Processing Record 26 of Set 12 | sambava
# Processing Record 27 of Set 12 | padang
# Processing Record 28 of Set 12 | sur
# Processing Record 29 of Set 12 | tuatapere
# Processing Record 30 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 12 | cayenne
# Processing Record 32 of Set 12 | saurimo
# Processing Record 33 of Set 12 | tiszaalpar
# Processing Record 34 of Set 12 | tikhvin
# Processing Record 35 of Set 12 | palmer
# Processing Record 36 of Set 12 | santa fe
# Processing Record 37 of Set 12 | cabra
# Processing Record 38 of Set 12 | ingham
# Processing Record 39 of Set 12 | kamina
# Processing Record 40 of Set 12 | port keats
# Processing Record 41 of Set 12 | turukhansk
# Processing Record 42 of Set 12 | brindisi
# Processing Record 43 of Set 12 | pokaran
# Processing Record 44 of Set 12 | pundaguitan
# Processing Record 45 of Set 12 | ponta delgada
# Processing Record 46 of Set 12 | tommot
# Processing Record 47 of Set 12 | porto velho
# Processing Record 48 of Set 12 | dalinghe
# City not found. Skipping...
# Processing Record 49 of Set 12 | zilupe
# Processing Record 50 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 13 | moyale
# Processing Record 2 of Set 13 | nizwa
# Processing Record 3 of Set 13 | emerald
# Processing Record 4 of Set 13 | dnipryany
# Processing Record 5 of Set 13 | marystown
# Processing Record 6 of Set 13 | duncan
# Processing Record 7 of Set 13 | nyurba
# Processing Record 8 of Set 13 | robertsport
# Processing Record 9 of Set 13 | medea
# Processing Record 10 of Set 13 | msanga
# Processing Record 11 of Set 13 | kyzyl-suu
# Processing Record 12 of Set 13 | erken-shakhar
# City not found. Skipping...
# Processing Record 13 of Set 13 | bull savanna
# Processing Record 14 of Set 13 | numazu
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | mae hong son
# Processing Record 17 of Set 13 | akyab
# Processing Record 18 of Set 13 | tazovskiy
# Processing Record 19 of Set 13 | bangalore
# Processing Record 20 of Set 13 | poum
# Processing Record 21 of Set 13 | gengenbach
# Processing Record 22 of Set 13 | kunda
# Processing Record 23 of Set 13 | buseresere
# Processing Record 24 of Set 13 | talas
# Processing Record 25 of Set 13 | novyye burasy
# Processing Record 26 of Set 13 | portland
# Processing Record 27 of Set 13 | colquechaca
# Processing Record 28 of Set 13 | el alto
# Processing Record 29 of Set 13 | mossendjo
# Processing Record 30 of Set 13 | tsabong
# Processing Record 31 of Set 13 | puerto escondido
# Processing Record 32 of Set 13 | verkhoyansk
# Processing Record 33 of Set 13 | diffa
# Processing Record 34 of Set 13 | valente
# Processing Record 35 of Set 13 | langfang
# Processing Record 36 of Set 13 | dalnerechensk
# Processing Record 37 of Set 13 | cordoba
# Processing Record 38 of Set 13 | taganak
# Processing Record 39 of Set 13 | namatanai
# Processing Record 40 of Set 13 | batagay-alyta
# Processing Record 41 of Set 13 | njombe
# Processing Record 42 of Set 13 | kamaishi
# Processing Record 43 of Set 13 | ust-ordynskiy
# Processing Record 44 of Set 13 | ulladulla
# Processing Record 45 of Set 13 | siauliai
# Processing Record 46 of Set 13 | lubao
# Processing Record 47 of Set 13 | tarakan
# Processing Record 48 of Set 13 | visby
# Processing Record 49 of Set 13 | karakose
# City not found. Skipping...
# Processing Record 50 of Set 13 | palmerston
# Processing Record 1 of Set 14 | high prairie
# Processing Record 2 of Set 14 | beaune
# Processing Record 3 of Set 14 | gat
# Processing Record 4 of Set 14 | demirci
# Processing Record 5 of Set 14 | sento se
# City not found. Skipping...
# Processing Record 6 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 14 | torit
# Processing Record 8 of Set 14 | truro
# Processing Record 9 of Set 14 | mount isa
# Processing Record 10 of Set 14 | kiama
# Processing Record 11 of Set 14 | mandalgovi
# Processing Record 12 of Set 14 | pafos
# Processing Record 13 of Set 14 | aksu
# Processing Record 14 of Set 14 | bereda
# Processing Record 15 of Set 14 | atambua
# Processing Record 16 of Set 14 | slave lake
# Processing Record 17 of Set 14 | aleksandrov gay
# Processing Record 18 of Set 14 | sikonge
# Processing Record 19 of Set 14 | shubarshi
# Processing Record 20 of Set 14 | cepu
# Processing Record 21 of Set 14 | solihull
# Processing Record 22 of Set 14 | camana
# Processing Record 23 of Set 14 | half moon bay
# Processing Record 24 of Set 14 | meulaboh
# Processing Record 25 of Set 14 | den helder
# Processing Record 26 of Set 14 | inverell
# Processing Record 27 of Set 14 | trabzon
# Processing Record 28 of Set 14 | villanueva de la serena
# Processing Record 29 of Set 14 | hay river
# Processing Record 30 of Set 14 | humaita
# Processing Record 31 of Set 14 | san pedro
# Processing Record 32 of Set 14 | thunder bay
# Processing Record 33 of Set 14 | omsukchan
# Processing Record 34 of Set 14 | bitung
# Processing Record 35 of Set 14 | shingu
# Processing Record 36 of Set 14 | haines junction
# Processing Record 37 of Set 14 | lethem
# Processing Record 38 of Set 14 | kelvington
# Processing Record 39 of Set 14 | port lavaca
# Processing Record 40 of Set 14 | baykit
# Processing Record 41 of Set 14 | grand-santi
# Processing Record 42 of Set 14 | sirsilla
# Processing Record 43 of Set 14 | salinopolis
# Processing Record 44 of Set 14 | bowen
# Processing Record 45 of Set 14 | lac-megantic
# Processing Record 46 of Set 14 | skovde
# City not found. Skipping...
# Processing Record 47 of Set 14 | raymond
# Processing Record 48 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 14 | saint-joseph
# Processing Record 50 of Set 14 | gabriel leyva solano
# Processing Record 1 of Set 15 | lata
# Processing Record 2 of Set 15 | turayf
# Processing Record 3 of Set 15 | limulunga
# Processing Record 4 of Set 15 | saint-pierre
# Processing Record 5 of Set 15 | veraval
# Processing Record 6 of Set 15 | khalkhal
# Processing Record 7 of Set 15 | sinnamary
# Processing Record 8 of Set 15 | dongning
# Processing Record 9 of Set 15 | dana point
# Processing Record 10 of Set 15 | ndjole
# Processing Record 11 of Set 15 | west bay
# Processing Record 12 of Set 15 | arecibo
# Processing Record 13 of Set 15 | kurgan
# Processing Record 14 of Set 15 | perepravnaya
# Processing Record 15 of Set 15 | pangkalanbuun
# Processing Record 16 of Set 15 | aguimes
# Processing Record 17 of Set 15 | akdepe
# Processing Record 18 of Set 15 | beloha
# Processing Record 19 of Set 15 | ust-omchug
# Processing Record 20 of Set 15 | kendari
# Processing Record 21 of Set 15 | powell
# Processing Record 22 of Set 15 | shellbrook
# Processing Record 23 of Set 15 | fort-shevchenko
# Processing Record 24 of Set 15 | mayo
# Processing Record 25 of Set 15 | abeche
# Processing Record 26 of Set 15 | iroquois falls
# Processing Record 27 of Set 15 | binga
# Processing Record 28 of Set 15 | mundybash
# Processing Record 29 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 15 | imperatriz
# Processing Record 31 of Set 15 | guerrero negro
# Processing Record 32 of Set 15 | komsomolskiy
# Processing Record 33 of Set 15 | lima
# Processing Record 34 of Set 15 | coahuayana
# Processing Record 35 of Set 15 | sayalgudi
# City not found. Skipping...
# Processing Record 36 of Set 15 | ko samui
# Processing Record 37 of Set 15 | kodinsk
# Processing Record 38 of Set 15 | santa isabel do rio negro
# Processing Record 39 of Set 15 | kendallville
# Processing Record 40 of Set 15 | johnstown
# Processing Record 41 of Set 15 | sao felix do xingu
# Processing Record 42 of Set 15 | alakurtti
# Processing Record 43 of Set 15 | shcholkine
# City not found. Skipping...
# Processing Record 44 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 15 | huarmey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 687

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     47.86        46           0        3.44
# 1   Butaritari   3.0707  172.7902     81.36        78          58       17.25
# 2       Neiafu -18.6500 -173.9833     77.68        78          40       11.50
# 3  New Norfolk -42.7826  147.0587     48.70        84         100        2.06
# 4  Tuktoyaktuk  69.4541 -133.0374     29.08        76         100        9.17
# 5    Vestmanna  62.1564   -7.1664     49.12        81          75       24.16
# 6       Trairi  -3.2778  -39.2689     82.09        66           7       16.06
# 7      Newport  51.5877   -2.9984     58.82        75          12        7.07
# 8        Vaini -21.2000 -175.2000     75.36        88          40        9.22
# 9        Namie  37.4833  141.0000     61.99        95         100        4.65
#
#   Country Current Description
# 0      AR           clear sky
# 1      KI          light rain
# 2      TO    scattered clouds
# 3      AU     overcast clouds
# 4      CA     overcast clouds
# 5      FO       broken clouds
# 6      BR           clear sky
# 7      GB          few clouds
# 8      TO    scattered clouds
# 9      JP     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000  -68.3000     47.86        46           0
# 1   Butaritari      KI   3.0707  172.7902     81.36        78          58
# 2       Neiafu      TO -18.6500 -173.9833     77.68        78          40
# 3  New Norfolk      AU -42.7826  147.0587     48.70        84         100
# 4  Tuktoyaktuk      CA  69.4541 -133.0374     29.08        76         100
# 5    Vestmanna      FO  62.1564   -7.1664     49.12        81          75
# 6       Trairi      BR  -3.2778  -39.2689     82.09        66           7
# 7      Newport      GB  51.5877   -2.9984     58.82        75          12
# 8        Vaini      TO -21.2000 -175.2000     75.36        88          40
# 9        Namie      JP  37.4833  141.0000     61.99        95         100
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1       17.25          light rain
# 2       11.50    scattered clouds
# 3        2.06     overcast clouds
# 4        9.17     overcast clouds
# 5       24.16       broken clouds
# 6       16.06           clear sky
# 7        7.07          few clouds
# 8        9.22    scattered clouds
# 9        4.65     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index=False)
